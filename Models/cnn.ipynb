# %% [markdown]
# Import Libraries

# %%
import torch
import torch.nn as nn
from torch.hub import load_state_dict_from_url
from torch.utils.model_zoo import load_url as load_state_dict_from_url
from typing import Type, Any, Callable, Union, List, Dict, Optional, cast
from torch import Tensor
from collections import OrderedDict

# %% [markdown]
# Build New Model

# %%
import torchvision.models as models
rnext = models.resnext101_32x8d(pretrained=True)
# Out:
# Downloading: "https://download.pytorch.org/models/resnext101_32x8d-8ba56ff5.pth" to /root/.cache/torch/hub/checkpoints/resnext101_32x8d-8ba56ff5.pth
#   0%|          | 0.00/340M [00:00<?, ?B/s]

# %%
children_counter = 0
for n,c in rnext.named_children():
    print("Children Counter: ",children_counter," Layer Name: ",n,)
    children_counter+=1
# Out:
# Children Counter:  0  Layer Name:  conv1
# Children Counter:  1  Layer Name:  bn1
# Children Counter:  2  Layer Name:  relu
# Children Counter:  3  Layer Name:  maxpool
# Children Counter:  4  Layer Name:  layer1
# Children Counter:  5  Layer Name:  layer2
# Children Counter:  6  Layer Name:  layer3
# Children Counter:  7  Layer Name:  layer4
# Children Counter:  8  Layer Name:  avgpool
# Children Counter:  9  Layer Name:  fc

# %%
from google.colab import drive
drive.mount('/content/drive',force_remount=True)
# Out:
# Mounted at /content/drive

# %%
from PIL import Image
import cv2
import torchvision.transforms as transforms
import collections
import random
from random import seed, choice, sample
import os
import json
from google.colab.patches import cv2_imshow
import sys
import time
import matplotlib
import matplotlib.pylab as plt
plt.rcParams["axes.grid"] = False
from os.path import exists, join, basename, splitext
import csv
import glob

# %%
# %matplotlib inline
import os
import sys
import json
import random
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import cv2
import skimage.transform
from PIL import Image
from collections import Counter
from tqdm.notebook import tqdm

import torch
torch.cuda.empty_cache()
import torch.backends.cudnn as cudnn
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import Dataset, DataLoader
from torch.nn.utils.rnn import pack_padded_sequence
from nltk.translate.bleu_score import corpus_bleu

import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
import numpy as np
import re
from tqdm import tqdm

from gensim.models.fasttext import FastText
 
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
import seaborn as sns
import matplotlib.pyplot as plt

# %%
os.chdir('/content/drive/My Drive/Final Year Project/')

# %%
print(os.path.abspath('.'))
# Out:
# /content/drive/.shortcut-targets-by-id/1sz5w7NJWd5pUCRXsoinjyyZ-EUMh1tbM/Final Year Project

# %%
filename = '/content/drive/My Drive/Final Year Project/input_images_train.txt'
read_file = open(filename,"r") 

train_image_paths = []
train_image_names = []
#print("Output of Read function is ")
data_read = read_file.read()
data_into_list = data_read.split("\n")
#print(data_into_list)
for i in range(len(data_into_list)):
    if(len(data_into_list[i])>1):
        train_image_paths.append(data_into_list[i])
        path = data_into_list[i]
        name_list = path.split("/")
        name = name_list[len(name_list)-1]
        #print(path)
        train_image_names.append(name)
print("No. of images: ",len(train_image_paths), len(train_image_names))
# Out:
# No. of images:  23431 23431

# %%
filename = '/content/drive/My Drive/Final Year Project/input_images_val.txt'
read_file = open(filename,"r") 

val_image_paths = []
val_image_names = []
#print("Output of Read function is ")
data_read = read_file.read()
data_into_list = data_read.split("\n")
#print(data_into_list)
for i in range(len(data_into_list)):
    if(len(data_into_list[i])>1):
        val_image_paths.append(data_into_list[i])
        path = data_into_list[i]
        name_list = path.split("/")
        name = name_list[len(name_list)-1]
        #print(path)
        val_image_names.append(name)
print("No. of images: ",len(val_image_paths), len(val_image_names))
# Out:
# No. of images:  7750 7750

# %%
image_paths = []
image_names = []

for i in range(5):
  image_paths.append(train_image_paths[i])
  image_names.append(train_image_names[i])

print(len(image_paths), len(image_names))
# Out:
# 5 5

# %%
# sets device to GPU if available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
class EncoderCNN(nn.Module):
    def __init__(self, enc_image_size=14):
        super(EncoderCNN, self).__init__()
        self.enc_image_size = enc_image_size

        # pretrained ImageNet ResNeXt-101
        resnext = models.resnext101_32x8d(pretrained=True)

        # remove linear and pool layers
        modules = list(resnext.children())[:-2]
        #print(modules)
        self.resnext = nn.Sequential(*modules)

        # resize image to fixed size using adaptive pool to allow input images of variable size
        self.adaptive_pool = nn.AvgPool2d((enc_image_size, enc_image_size))

        self.fine_tune()

    def fine_tune(self, fine_tune=True):
        """
        Allow or prevent computation of the gradients for convolutional blocks 2 through 4 of the image encoder.
        :param fine_tune: boolean
        """
        for param in self.resnext.parameters():
            param.requires_grad = False
        # if fine-tuning, fine-tune convolutional blocks 2 through 4
        for child in list(self.resnext.children())[5:]:
            for param in child.parameters():
                param.requires_grad = fine_tune
    
    def forward(self, images):
        """
        Forward propagation.
        :param images: images, a tensor of dim (batch_size, 3, image_size, image_size)
        :return enc_images: encoded repr of images, a tensor of dim (batch_size, enc_image_size, enc_image_size, 2048)
        """
        out = self.resnext(images)       # (batch_size, 2048, image_size/32, image_size/32)
        #out = self.adaptive_pool(out)   # (batch_size, 2048, enc_image_size, enc_image_size)
        #out = out.permute(0, 2, 3, 1)   # (batch_size, enc_image_size, enc_image_size, 2048)
        print(out.size())
        out = out.detach().to("cpu").numpy()
        #print(out.shape) 
        return out

# %%
fine_tune_encoder = False  # fine-tune encoder?
encoder_lr = 1e-4  # learning rate for encoder if fine-tuning

encoder = EncoderCNN()
encoder.fine_tune(fine_tune_encoder)
encoder_optimizer = optim.Adam(params=filter(lambda p: p.requires_grad, encoder.parameters()), lr=encoder_lr) if fine_tune_encoder else None

# %%
path = '/content/drive/My Drive/Final Year Project/cnn_features/'
for i in range(len(image_paths)):
    #read and pre-process image
    #print("CNN Encoding for: ",image_names[i])
    name = image_names[i]
    name = name[:len(name)-4]
    print(name)
    img = Image.open(val_image_paths[i]).convert('RGB')
    img = np.array(img)
    img = cv2.resize(img, (256, 256))

    # sanity check
    assert img.shape == (256, 256, 3)
    assert np.max(img) <= 255

    transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    ])

    img = transform(img)    # (3, 256, 256)
    
    np_path = path + name
    #print(np_path)
    #print(img.shape)
    out = encoder(img.unsqueeze(0))
    #print(out.dtype, out.shape)
    np.save(np_path, out)
    #data['cnn_vector'][i] = out
# Out:
# Streaming output truncated to the last 5000 lines.
# VizWiz_train_00018433
# VizWiz_train_00018434
# VizWiz_train_00018435
# VizWiz_train_00018436
# VizWiz_train_00018437
# VizWiz_train_00018438
# VizWiz_train_00018439
# VizWiz_train_00018440
# VizWiz_train_00018441
# VizWiz_train_00018442
# VizWiz_train_00018443
# VizWiz_train_00018444
# VizWiz_train_00018445
# VizWiz_train_00018446
# VizWiz_train_00018447
# VizWiz_train_00018448
# VizWiz_train_00018449
# VizWiz_train_00018450
# VizWiz_train_00018451
# VizWiz_train_00018452
# VizWiz_train_00018453
# VizWiz_train_00018454
# VizWiz_train_00018455
# VizWiz_train_00018456
# VizWiz_train_00018457
# VizWiz_train_00018458
# VizWiz_train_00018459
# VizWiz_train_00020020
# VizWiz_train_00020021
# VizWiz_train_00020022
# VizWiz_train_00020023
# VizWiz_train_00020024
# VizWiz_train_00020025
# VizWiz_train_00020026
# VizWiz_train_00020027
# VizWiz_train_00020028
# VizWiz_train_00020029
# VizWiz_train_00020030
# VizWiz_train_00020031
# VizWiz_train_00020032
# VizWiz_train_00020033
# VizWiz_train_00020034
# VizWiz_train_00020035
# VizWiz_train_00020036
# VizWiz_train_00020037
# VizWiz_train_00020038
# VizWiz_train_00020039
# VizWiz_train_00020040
# VizWiz_train_00020041
# VizWiz_train_00020042
# VizWiz_train_00020043
# VizWiz_train_00020044
# VizWiz_train_00020045
# VizWiz_train_00020046
# VizWiz_train_00020047
# VizWiz_train_00020048
# VizWiz_train_00020049
# VizWiz_train_00020050
# VizWiz_train_00020051
# VizWiz_train_00020052
# VizWiz_train_00020053
# VizWiz_train_00020054
# VizWiz_train_00020055
# VizWiz_train_00020056
# VizWiz_train_00020057
# VizWiz_train_00020058
# VizWiz_train_00020059
# VizWiz_train_00020060
# VizWiz_train_00020061
# VizWiz_train_00020062
# VizWiz_train_00020063
# VizWiz_train_00020064
# VizWiz_train_00020065
# VizWiz_train_00020066
# VizWiz_train_00020067
# VizWiz_train_00020068
# VizWiz_train_00020069
# VizWiz_train_00020070
# VizWiz_train_00020071
# VizWiz_train_00020072
# VizWiz_train_00020073
# VizWiz_train_00020074
# VizWiz_train_00020075
# VizWiz_train_00020076
# VizWiz_train_00020077
# VizWiz_train_00020078
# VizWiz_train_00020079
# VizWiz_train_00020080
# VizWiz_train_00020081
# VizWiz_train_00020082
# VizWiz_train_00020083
# VizWiz_train_00020084
# VizWiz_train_00020085
# VizWiz_train_00020086
# VizWiz_train_00020087
# VizWiz_train_00020088
# VizWiz_train_00020089
# VizWiz_train_00020090
# VizWiz_train_00020091
# VizWiz_train_00020092
# VizWiz_train_00020093
# VizWiz_train_00020094
# VizWiz_train_00020095
# VizWiz_train_00020096
# VizWiz_train_00020097
# VizWiz_train_00020098
# VizWiz_train_00020099
# VizWiz_train_00020100
# VizWiz_train_00020101
# VizWiz_train_00020102
# VizWiz_train_00020103
# VizWiz_train_00020104
# VizWiz_train_00020105
# VizWiz_train_00020106
# VizWiz_train_00020107
# VizWiz_train_00020108
# VizWiz_train_00020109
# VizWiz_train_00020110
# VizWiz_train_00020111
# VizWiz_train_00020112
# VizWiz_train_00020113
# VizWiz_train_00020114
# VizWiz_train_00020115
# VizWiz_train_00020116
# VizWiz_train_00020117
# VizWiz_train_00020118
# VizWiz_train_00020119
# VizWiz_train_00020120
# VizWiz_train_00020121
# VizWiz_train_00020122
# VizWiz_train_00020123
# VizWiz_train_00020124
# VizWiz_train_00020125
# VizWiz_train_00020126
# VizWiz_train_00020127
# VizWiz_train_00020128
# VizWiz_train_00020129
# VizWiz_train_00020130
# VizWiz_train_00020131
# VizWiz_train_00020132
# VizWiz_train_00020133
# VizWiz_train_00020134
# VizWiz_train_00020135
# VizWiz_train_00020136
# VizWiz_train_00020137
# VizWiz_train_00020138
# VizWiz_train_00020139
# VizWiz_train_00020140
# VizWiz_train_00020141
# VizWiz_train_00020142
# VizWiz_train_00020143
# VizWiz_train_00020144
# VizWiz_train_00020145
# VizWiz_train_00020146
# VizWiz_train_00020147
# VizWiz_train_00020148
# VizWiz_train_00020149
# VizWiz_train_00020150
# VizWiz_train_00020151
# VizWiz_train_00020152
# VizWiz_train_00020153
# VizWiz_train_00020154
# VizWiz_train_00020155
# VizWiz_train_00020156
# VizWiz_train_00020157
# VizWiz_train_00020158
# VizWiz_train_00020159
# VizWiz_train_00020160
# VizWiz_train_00020161
# VizWiz_train_00020162
# VizWiz_train_00020163
# VizWiz_train_00020164
# VizWiz_train_00020165
# VizWiz_train_00020166
# VizWiz_train_00020167
# VizWiz_train_00020168
# VizWiz_train_00020169
# VizWiz_train_00020170
# VizWiz_train_00020171
# VizWiz_train_00020172
# VizWiz_train_00020173
# VizWiz_train_00020174
# VizWiz_train_00020175
# VizWiz_train_00020176
# VizWiz_train_00020177
# VizWiz_train_00020178
# VizWiz_train_00020179
# VizWiz_train_00020180
# VizWiz_train_00020181
# VizWiz_train_00020182
# VizWiz_train_00020183
# VizWiz_train_00020184
# VizWiz_train_00020185
# VizWiz_train_00020186
# VizWiz_train_00020187
# VizWiz_train_00020188
# VizWiz_train_00020189
# VizWiz_train_00020190
# VizWiz_train_00020191
# VizWiz_train_00020192
# VizWiz_train_00020193
# VizWiz_train_00020194
# VizWiz_train_00020195
# VizWiz_train_00020196
# VizWiz_train_00020197
# VizWiz_train_00020198
# VizWiz_train_00020199
# VizWiz_train_00020200
# VizWiz_train_00020201
# VizWiz_train_00020202
# VizWiz_train_00020203
# VizWiz_train_00020204
# VizWiz_train_00020205
# VizWiz_train_00020206
# VizWiz_train_00020207
# VizWiz_train_00020208
# VizWiz_train_00020209
# VizWiz_train_00020210
# VizWiz_train_00020211
# VizWiz_train_00020212
# VizWiz_train_00020213
# VizWiz_train_00020214
# VizWiz_train_00020215
# VizWiz_train_00020216
# VizWiz_train_00020217
# VizWiz_train_00020218
# VizWiz_train_00020219
# VizWiz_train_00020220
# VizWiz_train_00020221
# VizWiz_train_00020222
# VizWiz_train_00020223
# VizWiz_train_00020224
# VizWiz_train_00020225
# VizWiz_train_00020226
# VizWiz_train_00020227
# VizWiz_train_00020228
# VizWiz_train_00020229
# VizWiz_train_00020230
# VizWiz_train_00020231
# VizWiz_train_00020232
# VizWiz_train_00020233
# VizWiz_train_00020234
# VizWiz_train_00020235
# VizWiz_train_00020236
# VizWiz_train_00020237
# VizWiz_train_00020238
# VizWiz_train_00020239
# VizWiz_train_00020240
# VizWiz_train_00020241
# VizWiz_train_00020242
# VizWiz_train_00020243
# VizWiz_train_00020244
# VizWiz_train_00020245
# VizWiz_train_00020246
# VizWiz_train_00020247
# VizWiz_train_00020248
# VizWiz_train_00020249
# VizWiz_train_00020250
# VizWiz_train_00020251
# VizWiz_train_00020252
# VizWiz_train_00020253
# VizWiz_train_00020254
# VizWiz_train_00020255
# VizWiz_train_00020256
# VizWiz_train_00020257
# VizWiz_train_00020258
# VizWiz_train_00020259
# VizWiz_train_00020260
# VizWiz_train_00020261
# VizWiz_train_00020262
# VizWiz_train_00020263
# VizWiz_train_00020264
# VizWiz_train_00020265
# VizWiz_train_00020266
# VizWiz_train_00020267
# VizWiz_train_00020268
# VizWiz_train_00020269
# VizWiz_train_00020270
# VizWiz_train_00020271
# VizWiz_train_00020272
# VizWiz_train_00020273
# VizWiz_train_00020274
# VizWiz_train_00020275
# VizWiz_train_00020276
# VizWiz_train_00020277
# VizWiz_train_00020278
# VizWiz_train_00020279
# VizWiz_train_00020280
# VizWiz_train_00020281
# VizWiz_train_00020282
# VizWiz_train_00020283
# VizWiz_train_00020284
# VizWiz_train_00020285
# VizWiz_train_00020286
# VizWiz_train_00020287
# VizWiz_train_00020288
# VizWiz_train_00020289
# VizWiz_train_00020290
# VizWiz_train_00020291
# VizWiz_train_00020292
# VizWiz_train_00020293
# VizWiz_train_00020294
# VizWiz_train_00020295
# VizWiz_train_00020296
# VizWiz_train_00020297
# VizWiz_train_00020298
# VizWiz_train_00020299
# VizWiz_train_00020300
# VizWiz_train_00020301
# VizWiz_train_00020302
# VizWiz_train_00020303
# VizWiz_train_00020304
# VizWiz_train_00020305
# VizWiz_train_00020306
# VizWiz_train_00020307
# VizWiz_train_00020308
# VizWiz_train_00020309
# VizWiz_train_00020310
# VizWiz_train_00020311
# VizWiz_train_00020312
# VizWiz_train_00020313
# VizWiz_train_00020314
# VizWiz_train_00020315
# VizWiz_train_00020316
# VizWiz_train_00020317
# VizWiz_train_00020318
# VizWiz_train_00020319
# VizWiz_train_00020320
# VizWiz_train_00020321
# VizWiz_train_00020322
# VizWiz_train_00020323
# VizWiz_train_00020324
# VizWiz_train_00020325
# VizWiz_train_00020326
# VizWiz_train_00020327
# VizWiz_train_00020328
# VizWiz_train_00020329
# VizWiz_train_00020330
# VizWiz_train_00020331
# VizWiz_train_00020332
# VizWiz_train_00020333
# VizWiz_train_00020334
# VizWiz_train_00020335
# VizWiz_train_00020336
# VizWiz_train_00020337
# VizWiz_train_00020338
# VizWiz_train_00020339
# VizWiz_train_00020340
# VizWiz_train_00020341
# VizWiz_train_00020342
# VizWiz_train_00020343
# VizWiz_train_00020344
# VizWiz_train_00020345
# VizWiz_train_00020346
# VizWiz_train_00020347
# VizWiz_train_00020348
# VizWiz_train_00020349
# VizWiz_train_00020350
# VizWiz_train_00020351
# VizWiz_train_00020352
# VizWiz_train_00020353
# VizWiz_train_00020354
# VizWiz_train_00020355
# VizWiz_train_00020356
# VizWiz_train_00020357
# VizWiz_train_00020358
# VizWiz_train_00020359
# VizWiz_train_00020360
# VizWiz_train_00020361
# VizWiz_train_00020362
# VizWiz_train_00020363
# VizWiz_train_00020364
# VizWiz_train_00020365
# VizWiz_train_00020366
# VizWiz_train_00020367
# VizWiz_train_00020368
# VizWiz_train_00020369
# VizWiz_train_00020370
# VizWiz_train_00020371
# VizWiz_train_00020372
# VizWiz_train_00020373
# VizWiz_train_00020374
# VizWiz_train_00020375
# VizWiz_train_00020376
# VizWiz_train_00020377
# VizWiz_train_00020378
# VizWiz_train_00020379
# VizWiz_train_00020380
# VizWiz_train_00020381
# VizWiz_train_00020382
# VizWiz_train_00020383
# VizWiz_train_00020384
# VizWiz_train_00020385
# VizWiz_train_00020386
# VizWiz_train_00020387
# VizWiz_train_00020388
# VizWiz_train_00020389
# VizWiz_train_00020390
# VizWiz_train_00020391
# VizWiz_train_00020392
# VizWiz_train_00020393
# VizWiz_train_00020394
# VizWiz_train_00020395
# VizWiz_train_00020396
# VizWiz_train_00020397
# VizWiz_train_00020398
# VizWiz_train_00020399
# VizWiz_train_00020400
# VizWiz_train_00020401
# VizWiz_train_00020402
# VizWiz_train_00020403
# VizWiz_train_00020404
# VizWiz_train_00020405
# VizWiz_train_00020406
# VizWiz_train_00020407
# VizWiz_train_00020408
# VizWiz_train_00020409
# VizWiz_train_00020410
# VizWiz_train_00020411
# VizWiz_train_00020412
# VizWiz_train_00020413
# VizWiz_train_00020414
# VizWiz_train_00020415
# VizWiz_train_00020416
# VizWiz_train_00020417
# VizWiz_train_00020418
# VizWiz_train_00020419
# VizWiz_train_00020420
# VizWiz_train_00020421
# VizWiz_train_00020422
# VizWiz_train_00020423
# VizWiz_train_00020424
# VizWiz_train_00020425
# VizWiz_train_00020426
# VizWiz_train_00020427
# VizWiz_train_00020428
# VizWiz_train_00020429
# VizWiz_train_00020430
# VizWiz_train_00020431
# VizWiz_train_00020432
# VizWiz_train_00020433
# VizWiz_train_00020434
# VizWiz_train_00020435
# VizWiz_train_00020436
# VizWiz_train_00020437
# VizWiz_train_00020438
# VizWiz_train_00020439
# VizWiz_train_00020440
# VizWiz_train_00020441
# VizWiz_train_00020442
# VizWiz_train_00020443
# VizWiz_train_00020444
# VizWiz_train_00020445
# VizWiz_train_00020446
# VizWiz_train_00020447
# VizWiz_train_00020448
# VizWiz_train_00020449
# VizWiz_train_00020450
# VizWiz_train_00020451
# VizWiz_train_00020452
# VizWiz_train_00020453
# VizWiz_train_00020454
# VizWiz_train_00020455
# VizWiz_train_00020456
# VizWiz_train_00020457
# VizWiz_train_00020458
# VizWiz_train_00020459
# VizWiz_train_00020460
# VizWiz_train_00020461
# VizWiz_train_00020462
# VizWiz_train_00020463
# VizWiz_train_00020464
# VizWiz_train_00020465
# VizWiz_train_00020466
# VizWiz_train_00020467
# VizWiz_train_00020468
# VizWiz_train_00020469
# VizWiz_train_00020470
# VizWiz_train_00020471
# VizWiz_train_00020472
# VizWiz_train_00020473
# VizWiz_train_00020474
# VizWiz_train_00020475
# VizWiz_train_00020476
# VizWiz_train_00020477
# VizWiz_train_00020478
# VizWiz_train_00020479
# VizWiz_train_00020480
# VizWiz_train_00020481
# VizWiz_train_00020482
# VizWiz_train_00020483
# VizWiz_train_00020484
# VizWiz_train_00020485
# VizWiz_train_00020486
# VizWiz_train_00020487
# VizWiz_train_00020488
# VizWiz_train_00020489
# VizWiz_train_00020490
# VizWiz_train_00020491
# VizWiz_train_00020492
# VizWiz_train_00020493
# VizWiz_train_00020494
# VizWiz_train_00020495
# VizWiz_train_00020496
# VizWiz_train_00020497
# VizWiz_train_00020498
# VizWiz_train_00020499
# VizWiz_train_00020500
# VizWiz_train_00020501
# VizWiz_train_00020502
# VizWiz_train_00020503
# VizWiz_train_00020504
# VizWiz_train_00020505
# VizWiz_train_00020506
# VizWiz_train_00020507
# VizWiz_train_00020508
# VizWiz_train_00020509
# VizWiz_train_00020510
# VizWiz_train_00020511
# VizWiz_train_00020512
# VizWiz_train_00020513
# VizWiz_train_00020514
# VizWiz_train_00020515
# VizWiz_train_00020516
# VizWiz_train_00020517
# VizWiz_train_00020518
# VizWiz_train_00020519
# VizWiz_train_00020520
# VizWiz_train_00020521
# VizWiz_train_00020522
# VizWiz_train_00020523
# VizWiz_train_00020524
# VizWiz_train_00020525
# VizWiz_train_00020526
# VizWiz_train_00020527
# VizWiz_train_00020528
# VizWiz_train_00020529
# VizWiz_train_00020530
# VizWiz_train_00020531
# VizWiz_train_00020532
# VizWiz_train_00020533
# VizWiz_train_00020534
# VizWiz_train_00020535
# VizWiz_train_00020536
# VizWiz_train_00020537
# VizWiz_train_00020538
# VizWiz_train_00020539
# VizWiz_train_00020540
# VizWiz_train_00020541
# VizWiz_train_00020542
# VizWiz_train_00020543
# VizWiz_train_00020544
# VizWiz_train_00020545
# VizWiz_train_00020546
# VizWiz_train_00020547
# VizWiz_train_00020548
# VizWiz_train_00020549
# VizWiz_train_00020550
# VizWiz_train_00020551
# VizWiz_train_00020552
# VizWiz_train_00020553
# VizWiz_train_00020554
# VizWiz_train_00020555
# VizWiz_train_00020556
# VizWiz_train_00020557
# VizWiz_train_00020558
# VizWiz_train_00020559
# VizWiz_train_00020560
# VizWiz_train_00020561
# VizWiz_train_00020562
# VizWiz_train_00020563
# VizWiz_train_00020564
# VizWiz_train_00020565
# VizWiz_train_00020566
# VizWiz_train_00020567
# VizWiz_train_00020568
# VizWiz_train_00020569
# VizWiz_train_00020570
# VizWiz_train_00020571
# VizWiz_train_00020572
# VizWiz_train_00020573
# VizWiz_train_00020574
# VizWiz_train_00020575
# VizWiz_train_00020576
# VizWiz_train_00020577
# VizWiz_train_00020578
# VizWiz_train_00020579
# VizWiz_train_00020580
# VizWiz_train_00020581
# VizWiz_train_00020582
# VizWiz_train_00020583
# VizWiz_train_00020584
# VizWiz_train_00020585
# VizWiz_train_00020586
# VizWiz_train_00020587
# VizWiz_train_00020588
# VizWiz_train_00020589
# VizWiz_train_00020590
# VizWiz_train_00020591
# VizWiz_train_00020592
# VizWiz_train_00020593
# VizWiz_train_00020594
# VizWiz_train_00020595
# VizWiz_train_00020596
# VizWiz_train_00020597
# VizWiz_train_00020598
# VizWiz_train_00020599
# VizWiz_train_00020600
# VizWiz_train_00020601
# VizWiz_train_00020602
# VizWiz_train_00020603
# VizWiz_train_00020604
# VizWiz_train_00020605
# VizWiz_train_00020606
# VizWiz_train_00020607
# VizWiz_train_00020608
# VizWiz_train_00020609
# VizWiz_train_00020610
# VizWiz_train_00020611
# ...
# VizWiz_train_00022706
# VizWiz_train_00022707
# VizWiz_train_00022708
# VizWiz_train_00022709
# VizWiz_train_00022710
# VizWiz_train_00022711
# VizWiz_train_00022712
# VizWiz_train_00022713
# VizWiz_train_00022714
# VizWiz_train_00022715
# VizWiz_train_00022716
# VizWiz_train_00022717
# VizWiz_train_00022718
# VizWiz_train_00022719
# VizWiz_train_00022720
# VizWiz_train_00022721
# VizWiz_train_00022722
# VizWiz_train_00022723
# VizWiz_train_00022724
# VizWiz_train_00022725
# VizWiz_train_00022726
# VizWiz_train_00022727
# VizWiz_train_00022728
# VizWiz_train_00022729
# VizWiz_train_00022730
# VizWiz_train_00022731
# VizWiz_train_00022732
# VizWiz_train_00022733
# VizWiz_train_00022734
# VizWiz_train_00022735
# VizWiz_train_00022736
# VizWiz_train_00022737
# VizWiz_train_00022738
# VizWiz_train_00022739
# VizWiz_train_00022740
# VizWiz_train_00022741
# VizWiz_train_00022742
# VizWiz_train_00022743
# VizWiz_train_00022744
# VizWiz_train_00022745
# VizWiz_train_00022746
# VizWiz_train_00022747
# VizWiz_train_00022748
# VizWiz_train_00022749
# VizWiz_train_00022750
# VizWiz_train_00022751
# VizWiz_train_00022752
# VizWiz_train_00022753
# VizWiz_train_00022754
# VizWiz_train_00022755
# VizWiz_train_00022756
# VizWiz_train_00022757
# VizWiz_train_00022758
# VizWiz_train_00022759
# VizWiz_train_00022760
# VizWiz_train_00022761
# VizWiz_train_00022762
# VizWiz_train_00022763
# VizWiz_train_00022764
# VizWiz_train_00022765
# VizWiz_train_00022766
# VizWiz_train_00022767
# VizWiz_train_00022768
# VizWiz_train_00022769
# VizWiz_train_00022770
# VizWiz_train_00022771
# VizWiz_train_00022772
# VizWiz_train_00022773
# VizWiz_train_00022774
# VizWiz_train_00022775
# VizWiz_train_00022776
# VizWiz_train_00022777
# VizWiz_train_00022778
# VizWiz_train_00022779
# VizWiz_train_00022780
# VizWiz_train_00022781
# VizWiz_train_00022782
# VizWiz_train_00022783
# VizWiz_train_00022784
# VizWiz_train_00022785
# VizWiz_train_00022786
# VizWiz_train_00022787
# VizWiz_train_00022788
# VizWiz_train_00022789
# VizWiz_train_00022790
# VizWiz_train_00022791
# VizWiz_train_00022792
# VizWiz_train_00022793
# VizWiz_train_00022794
# VizWiz_train_00022795
# VizWiz_train_00022796
# VizWiz_train_00022797
# VizWiz_train_00022798
# VizWiz_train_00022799
# VizWiz_train_00022800
# VizWiz_train_00022801
# VizWiz_train_00022802
# VizWiz_train_00022803
# VizWiz_train_00022804
# VizWiz_train_00022805
# VizWiz_train_00022806
# VizWiz_train_00022807
# VizWiz_train_00022808
# VizWiz_train_00022809
# VizWiz_train_00022810
# VizWiz_train_00022811
# VizWiz_train_00022812
# VizWiz_train_00022813
# VizWiz_train_00022814
# VizWiz_train_00022815
# VizWiz_train_00022816
# VizWiz_train_00022817
# VizWiz_train_00022818
# VizWiz_train_00022819
# VizWiz_train_00022820
# VizWiz_train_00022821
# VizWiz_train_00022822
# VizWiz_train_00022823
# VizWiz_train_00022824
# VizWiz_train_00022825
# VizWiz_train_00022826
# VizWiz_train_00022827
# VizWiz_train_00022828
# VizWiz_train_00022829
# VizWiz_train_00022830
# VizWiz_train_00022831
# VizWiz_train_00022832
# VizWiz_train_00022833
# VizWiz_train_00022834
# VizWiz_train_00022835
# VizWiz_train_00022836
# VizWiz_train_00022837
# VizWiz_train_00022838
# VizWiz_train_00022839
# VizWiz_train_00022840
# VizWiz_train_00022841
# VizWiz_train_00022842
# VizWiz_train_00022843
# VizWiz_train_00022844
# VizWiz_train_00022845
# VizWiz_train_00022846
# VizWiz_train_00022847
# VizWiz_train_00022848
# VizWiz_train_00022849
# VizWiz_train_00022850
# VizWiz_train_00022851
# VizWiz_train_00022852
# VizWiz_train_00022853
# VizWiz_train_00022854
# VizWiz_train_00022855
# VizWiz_train_00022856
# VizWiz_train_00022857
# VizWiz_train_00022858
# VizWiz_train_00022859
# VizWiz_train_00022860
# VizWiz_train_00022861
# VizWiz_train_00022862
# VizWiz_train_00022863
# VizWiz_train_00022864
# VizWiz_train_00022865
# VizWiz_train_00022866
# VizWiz_train_00022867
# VizWiz_train_00022868
# VizWiz_train_00022869
# VizWiz_train_00022870
# VizWiz_train_00022871
# VizWiz_train_00022872
# VizWiz_train_00022873
# VizWiz_train_00022874
# VizWiz_train_00022875
# VizWiz_train_00022876
# VizWiz_train_00022877
# VizWiz_train_00022878
# VizWiz_train_00022879
# VizWiz_train_00022880
# VizWiz_train_00022881
# VizWiz_train_00022882
# VizWiz_train_00022883
# VizWiz_train_00022884
# VizWiz_train_00022885
# VizWiz_train_00022886
# VizWiz_train_00022887
# VizWiz_train_00022888
# VizWiz_train_00022889
# VizWiz_train_00022890
# VizWiz_train_00022891
# VizWiz_train_00022892
# VizWiz_train_00022893
# VizWiz_train_00022894
# VizWiz_train_00022895
# VizWiz_train_00022896
# VizWiz_train_00022897
# VizWiz_train_00022898
# VizWiz_train_00022899
# VizWiz_train_00022900
# VizWiz_train_00022901
# VizWiz_train_00022902
# VizWiz_train_00022903
# VizWiz_train_00022904
# VizWiz_train_00022905
# VizWiz_train_00022906
# VizWiz_train_00022907
# VizWiz_train_00022908
# VizWiz_train_00022909
# VizWiz_train_00022910
# VizWiz_train_00022911
# VizWiz_train_00022912
# VizWiz_train_00022913
# VizWiz_train_00022914
# VizWiz_train_00022915
# VizWiz_train_00022916
# VizWiz_train_00022917
# VizWiz_train_00022918
# VizWiz_train_00022919
# VizWiz_train_00022920
# VizWiz_train_00022921
# VizWiz_train_00022922
# VizWiz_train_00022923
# VizWiz_train_00022924
# VizWiz_train_00022925
# VizWiz_train_00022926
# VizWiz_train_00022927
# VizWiz_train_00022928
# VizWiz_train_00022929
# VizWiz_train_00022930
# VizWiz_train_00022931
# VizWiz_train_00022932
# VizWiz_train_00022933
# VizWiz_train_00022934
# VizWiz_train_00022935
# VizWiz_train_00022936
# VizWiz_train_00022937
# VizWiz_train_00022938
# VizWiz_train_00022939
# VizWiz_train_00022940
# VizWiz_train_00022941
# VizWiz_train_00022942
# VizWiz_train_00022943
# VizWiz_train_00022944
# VizWiz_train_00022945
# VizWiz_train_00022946
# VizWiz_train_00022947
# VizWiz_train_00022948
# VizWiz_train_00022949
# VizWiz_train_00022950
# VizWiz_train_00022951
# VizWiz_train_00022952
# VizWiz_train_00022953
# VizWiz_train_00022954
# VizWiz_train_00022955
# VizWiz_train_00022956
# VizWiz_train_00022957
# VizWiz_train_00022958
# VizWiz_train_00022959
# VizWiz_train_00022960
# VizWiz_train_00022961
# VizWiz_train_00022962
# VizWiz_train_00022963
# VizWiz_train_00022964
# VizWiz_train_00022965
# VizWiz_train_00022966
# VizWiz_train_00022967
# VizWiz_train_00022968
# VizWiz_train_00022969
# VizWiz_train_00022970
# VizWiz_train_00022971
# VizWiz_train_00022972
# VizWiz_train_00022973
# VizWiz_train_00022974
# VizWiz_train_00022975
# VizWiz_train_00022976
# VizWiz_train_00022977
# VizWiz_train_00022978
# VizWiz_train_00022979
# VizWiz_train_00022980
# VizWiz_train_00022981
# VizWiz_train_00022982
# VizWiz_train_00022983
# VizWiz_train_00022984
# VizWiz_train_00022985
# VizWiz_train_00022986
# VizWiz_train_00022987
# VizWiz_train_00022988
# VizWiz_train_00022989
# VizWiz_train_00022990
# VizWiz_train_00022991
# VizWiz_train_00022992
# VizWiz_train_00022993
# VizWiz_train_00022994
# VizWiz_train_00022995
# VizWiz_train_00022996
# VizWiz_train_00022997
# VizWiz_train_00022998
# VizWiz_train_00022999
# VizWiz_train_00023000
# VizWiz_train_00023001
# VizWiz_train_00023002
# VizWiz_train_00023003
# VizWiz_train_00023004
# VizWiz_train_00023005
# VizWiz_train_00023006
# VizWiz_train_00023007
# VizWiz_train_00023008
# VizWiz_train_00023009
# VizWiz_train_00023010
# VizWiz_train_00023011
# VizWiz_train_00023012
# VizWiz_train_00023013
# VizWiz_train_00023014
# VizWiz_train_00023015
# VizWiz_train_00023016
# VizWiz_train_00023017
# VizWiz_train_00023018
# VizWiz_train_00023019
# VizWiz_train_00023020
# VizWiz_train_00023021
# VizWiz_train_00023022
# VizWiz_train_00023023
# VizWiz_train_00023024
# VizWiz_train_00023025
# VizWiz_train_00023026
# VizWiz_train_00023027
# VizWiz_train_00023028
# VizWiz_train_00023029
# VizWiz_train_00023030
# VizWiz_train_00023031
# VizWiz_train_00023032
# VizWiz_train_00023033
# VizWiz_train_00023034
# VizWiz_train_00023035
# VizWiz_train_00023036
# VizWiz_train_00023037
# VizWiz_train_00023038
# VizWiz_train_00023039
# VizWiz_train_00023040
# VizWiz_train_00023041
# VizWiz_train_00023042
# VizWiz_train_00023043
# VizWiz_train_00023044
# VizWiz_train_00023045
# VizWiz_train_00023046
# VizWiz_train_00023047
# VizWiz_train_00023048
# VizWiz_train_00023049
# VizWiz_train_00023050
# VizWiz_train_00023051
# VizWiz_train_00023052
# VizWiz_train_00023053
# VizWiz_train_00023054
# VizWiz_train_00023055
# VizWiz_train_00023056
# VizWiz_train_00023057
# VizWiz_train_00023058
# VizWiz_train_00023059
# VizWiz_train_00023060
# VizWiz_train_00023061
# VizWiz_train_00023062
# VizWiz_train_00023063
# VizWiz_train_00023064
# VizWiz_train_00023065
# VizWiz_train_00023066
# VizWiz_train_00023067
# VizWiz_train_00023068
# VizWiz_train_00023069
# VizWiz_train_00023070
# VizWiz_train_00023071
# VizWiz_train_00023072
# VizWiz_train_00023073
# VizWiz_train_00023074
# VizWiz_train_00023075
# VizWiz_train_00023076
# VizWiz_train_00023077
# VizWiz_train_00023078
# VizWiz_train_00023079
# VizWiz_train_00023080
# VizWiz_train_00023081
# VizWiz_train_00023082
# VizWiz_train_00023083
# VizWiz_train_00023084
# VizWiz_train_00023085
# VizWiz_train_00023086
# VizWiz_train_00023087
# VizWiz_train_00023088
# VizWiz_train_00023089
# VizWiz_train_00023090
# VizWiz_train_00023091
# VizWiz_train_00023092
# VizWiz_train_00023093
# VizWiz_train_00023094
# VizWiz_train_00023095
# VizWiz_train_00023096
# VizWiz_train_00023097
# VizWiz_train_00023098
# VizWiz_train_00023099
# VizWiz_train_00023100
# VizWiz_train_00023101
# VizWiz_train_00023102
# VizWiz_train_00023103
# VizWiz_train_00023104
# VizWiz_train_00023105
# VizWiz_train_00023106
# VizWiz_train_00023107
# VizWiz_train_00023108
# VizWiz_train_00023109
# VizWiz_train_00023110
# VizWiz_train_00023111
# VizWiz_train_00023112
# VizWiz_train_00023113
# VizWiz_train_00023114
# VizWiz_train_00023115
# VizWiz_train_00023116
# VizWiz_train_00023117
# VizWiz_train_00023118
# VizWiz_train_00023119
# VizWiz_train_00023120
# VizWiz_train_00023121
# VizWiz_train_00023122
# VizWiz_train_00023123
# VizWiz_train_00023124
# VizWiz_train_00023125
# VizWiz_train_00023126
# VizWiz_train_00023127
# VizWiz_train_00023128
# VizWiz_train_00023129
# VizWiz_train_00023130
# VizWiz_train_00023131
# VizWiz_train_00023132
# VizWiz_train_00023133
# VizWiz_train_00023134
# VizWiz_train_00023135
# VizWiz_train_00023136
# VizWiz_train_00023137
# VizWiz_train_00023138
# VizWiz_train_00023139
# VizWiz_train_00023140
# VizWiz_train_00023141
# VizWiz_train_00023142
# VizWiz_train_00023143
# VizWiz_train_00023144
# VizWiz_train_00023145
# VizWiz_train_00023146
# VizWiz_train_00023147
# VizWiz_train_00023148
# VizWiz_train_00023149
# VizWiz_train_00023150
# VizWiz_train_00023151
# VizWiz_train_00023152
# VizWiz_train_00023153
# VizWiz_train_00023154
# VizWiz_train_00023155
# VizWiz_train_00023156
# VizWiz_train_00023157
# VizWiz_train_00023158
# VizWiz_train_00023159
# VizWiz_train_00023160
# VizWiz_train_00023161
# VizWiz_train_00023162
# VizWiz_train_00023163
# VizWiz_train_00023164
# VizWiz_train_00023165
# VizWiz_train_00023166
# VizWiz_train_00023167
# VizWiz_train_00023168
# VizWiz_train_00023169
# VizWiz_train_00023170
# VizWiz_train_00023171
# VizWiz_train_00023172
# VizWiz_train_00023173
# VizWiz_train_00023174
# VizWiz_train_00023175
# VizWiz_train_00023176
# VizWiz_train_00023177
# VizWiz_train_00023178
# VizWiz_train_00023179
# VizWiz_train_00023180
# VizWiz_train_00023181
# VizWiz_train_00023182
# VizWiz_train_00023183
# VizWiz_train_00023184
# VizWiz_train_00023185
# VizWiz_train_00023186
# VizWiz_train_00023187
# VizWiz_train_00023188
# VizWiz_train_00023189
# VizWiz_train_00023190
# VizWiz_train_00023191
# VizWiz_train_00023192
# VizWiz_train_00023193
# VizWiz_train_00023194
# VizWiz_train_00023195
# VizWiz_train_00023196
# VizWiz_train_00023197
# VizWiz_train_00023198
# VizWiz_train_00023199
# VizWiz_train_00023200
# VizWiz_train_00023201
# VizWiz_train_00023202
# VizWiz_train_00023203
# VizWiz_train_00023204
# VizWiz_train_00023205
# VizWiz_train_00023206
# VizWiz_train_00023207
# VizWiz_train_00023208
# VizWiz_train_00023209
# VizWiz_train_00023210
# VizWiz_train_00023211
# VizWiz_train_00023212
# VizWiz_train_00023213
# VizWiz_train_00023214
# VizWiz_train_00023215
# VizWiz_train_00023216
# VizWiz_train_00023217
# VizWiz_train_00023218
# VizWiz_train_00023219
# VizWiz_train_00023220
# VizWiz_train_00023221
# VizWiz_train_00023222
# VizWiz_train_00023223
# VizWiz_train_00023224
# VizWiz_train_00023225
# VizWiz_train_00023226
# VizWiz_train_00023227
# VizWiz_train_00023228
# VizWiz_train_00023229
# VizWiz_train_00023230
# VizWiz_train_00023231
# VizWiz_train_00023232
# VizWiz_train_00023233
# VizWiz_train_00023234
# VizWiz_train_00023235
# VizWiz_train_00023236
# VizWiz_train_00023237
# VizWiz_train_00023238
# VizWiz_train_00023239
# VizWiz_train_00023240
# VizWiz_train_00023241
# VizWiz_train_00023242
# VizWiz_train_00023243
# VizWiz_train_00023244
# VizWiz_train_00023245
# VizWiz_train_00023246
# VizWiz_train_00023247
# VizWiz_train_00023248
# VizWiz_train_00023249
# VizWiz_train_00023250
# VizWiz_train_00023251
# VizWiz_train_00023252
# VizWiz_train_00023253
# VizWiz_train_00023254
# VizWiz_train_00023255
# VizWiz_train_00023256
# VizWiz_train_00023257
# VizWiz_train_00023258
# VizWiz_train_00023259
# VizWiz_train_00023260
# VizWiz_train_00023261
# VizWiz_train_00023262
# VizWiz_train_00023263
# VizWiz_train_00023264
# VizWiz_train_00023265
# VizWiz_train_00023266
# VizWiz_train_00023267
# VizWiz_train_00023268
# VizWiz_train_00023269
# VizWiz_train_00023270
# VizWiz_train_00023271
# VizWiz_train_00023272
# VizWiz_train_00023273
# VizWiz_train_00023274
# VizWiz_train_00023275
# VizWiz_train_00023276
# VizWiz_train_00023277
# VizWiz_train_00023278
# VizWiz_train_00023279
# VizWiz_train_00023280
# VizWiz_train_00023281
# VizWiz_train_00023282
# VizWiz_train_00023283
# VizWiz_train_00023284
# VizWiz_train_00023285
# VizWiz_train_00023286
# VizWiz_train_00023287
# VizWiz_train_00023288
# VizWiz_train_00023289
# VizWiz_train_00023290
# VizWiz_train_00023291
# VizWiz_train_00023292
# VizWiz_train_00023293
# VizWiz_train_00023294
# VizWiz_train_00023295
# VizWiz_train_00023296
# VizWiz_train_00023297
# VizWiz_train_00023298
# VizWiz_train_00023299
# VizWiz_train_00023300
# VizWiz_train_00023301
# VizWiz_train_00023302
# VizWiz_train_00023303
# VizWiz_train_00023304
# VizWiz_train_00023305
# VizWiz_train_00023306
# VizWiz_train_00023307
# VizWiz_train_00023308
# VizWiz_train_00023309
# VizWiz_train_00023310
# VizWiz_train_00023311
# VizWiz_train_00023312
# VizWiz_train_00023313
# VizWiz_train_00023314
# VizWiz_train_00023315
# VizWiz_train_00023316
# VizWiz_train_00023317
# VizWiz_train_00023318
# VizWiz_train_00023319
# VizWiz_train_00023320
# VizWiz_train_00023321
# VizWiz_train_00023322
# VizWiz_train_00023323
# VizWiz_train_00023324
# VizWiz_train_00023325
# VizWiz_train_00023326
# VizWiz_train_00023327
# VizWiz_train_00023328
# VizWiz_train_00023329
# VizWiz_train_00023330
# VizWiz_train_00023331
# VizWiz_train_00023332
# VizWiz_train_00023333
# VizWiz_train_00023334
# VizWiz_train_00023335
# VizWiz_train_00023336
# VizWiz_train_00023337
# VizWiz_train_00023338
# VizWiz_train_00023339
# VizWiz_train_00023340
# VizWiz_train_00023341
# VizWiz_train_00023342
# VizWiz_train_00023343
# VizWiz_train_00023344
# VizWiz_train_00023345
# VizWiz_train_00023346
# VizWiz_train_00023347
# VizWiz_train_00023348
# VizWiz_train_00023349
# VizWiz_train_00023350
# VizWiz_train_00023351
# VizWiz_train_00023352
# VizWiz_train_00023353
# VizWiz_train_00023354
# VizWiz_train_00023355
# VizWiz_train_00023356
# VizWiz_train_00023357
# VizWiz_train_00023358
# VizWiz_train_00023359
# VizWiz_train_00023360
# VizWiz_train_00023361
# VizWiz_train_00023362
# VizWiz_train_00023363
# VizWiz_train_00023364
# VizWiz_train_00023365
# VizWiz_train_00023366
# VizWiz_train_00023367
# VizWiz_train_00023368
# VizWiz_train_00023369
# VizWiz_train_00023370
# VizWiz_train_00023371
# VizWiz_train_00023372
# VizWiz_train_00023373
# VizWiz_train_00023374
# VizWiz_train_00023375
# VizWiz_train_00023376
# VizWiz_train_00023377
# VizWiz_train_00023378
# VizWiz_train_00023379
# VizWiz_train_00023380
# VizWiz_train_00023381
# VizWiz_train_00023382
# VizWiz_train_00023383
# VizWiz_train_00023384
# VizWiz_train_00023385
# VizWiz_train_00023386
# VizWiz_train_00023387
# VizWiz_train_00023388
# VizWiz_train_00023389
# VizWiz_train_00023390
# VizWiz_train_00023391
# VizWiz_train_00023392
# VizWiz_train_00023393
# VizWiz_train_00023394
# VizWiz_train_00023395
# VizWiz_train_00023396
# VizWiz_train_00023397
# VizWiz_train_00023398
# VizWiz_train_00023399
# VizWiz_train_00023400
# VizWiz_train_00023401
# VizWiz_train_00023402
# VizWiz_train_00023403
# VizWiz_train_00023404
# VizWiz_train_00023405
# VizWiz_train_00023406
# VizWiz_train_00023407
# VizWiz_train_00023408
# VizWiz_train_00023409
# VizWiz_train_00023410
# VizWiz_train_00023411
# VizWiz_train_00023412
# VizWiz_train_00023413
# VizWiz_train_00023414
# VizWiz_train_00023415
# VizWiz_train_00023416
# VizWiz_train_00023417
# VizWiz_train_00023418
# VizWiz_train_00023419
# VizWiz_train_00023420
# VizWiz_train_00023421
# VizWiz_train_00023422
# VizWiz_train_00023423
# VizWiz_train_00023424
# VizWiz_train_00023425
# VizWiz_train_00023426
# VizWiz_train_00023427
# VizWiz_train_00023428
# VizWiz_train_00023429
# VizWiz_train_00023430
# 23431
# (1, 2048, 14, 14) float32
